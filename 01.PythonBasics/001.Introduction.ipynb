# %% [markdown]
# # Data Types
# - Numbers
# - Strings
# - Variables
# - Print Statements
# - Lists
# - Dictionaties
# - Booleans
# - Tuples
# - Sets

# %% [markdown]
# # Numbers

# %%
1+1
# Out:
# 2

# %%
5 * 3
# Out:
# 15

# %%
1/2
# Out:
# 0.5

# %%
2 ** 4
# Out:
# 16

# %%
2 * 4
# Out:
# 8

# %%
4/2
# Out:
# 2.0

# %%
4%2
# Out:
# 0

# %%
(2 + 3) * (5 + 5)
# Out:
# 50

# %%
(2 + 3) + (5 * 2)
# Out:
# 15

# %% [markdown]
# # Strings

# %%
"Rohit"
# Out:
# 'Rohit'

# %%
"Password@1234"
# Out:
# 'Password@1234'

# %%
1 + "25"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 1 + "25"
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
1 + 25
# Out:
# 26

# %%
"Rohit" * 25
# Out:
# 'RohitRohitRohitRohitRohitRohitRohitRohitRohitRohitRohitRohitRohitRohitRohitRohitRohitRohitRohitRohitRohitRohitRohitRohitRohit'

# %% [markdown]
# # Variables

# %%
number 1 = 1
# Out:
#   Cell In[17], line 1
#     number 1 = 1
#            ^
# SyntaxError: invalid syntax

# %%
number_1 = 10

# %%
number_2 = 10

# %%
number_1 + number_2
# Out:
# 20

# %% [markdown]
# # Print Statements

# %%
print("The total of Number 1 and Number 2 is :", number_1 + number_2)
# Out:
# The total of Number 1 and Number 2 is : 20

# %%
print(
    "The total of ", number_1, "+", number_2, "=", number_1 + number_2
)
# Out:
# The total of  10 + 10 = 20

# %%
print(f"The sum of {number_1} and {number_2} is {number_1 + number_2}")
# Out:
# The sum of 10 and 10 is 20

# %% [markdown]
# # Lists

# %%
data = ["Banana", "Apples", "Rice", 10, "Rohit", "Siva"]

# %%
data
# Out:
# ['Banana', 'Apples', 'Rice', 10, 'Rohit', 'Siva']

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
data[3]
# Out:
# 10

# %%
len(data)
# Out:
# 6

# %%
data[len(data)-1]
# Out:
# 'Siva'

# %%
data[-1]
# Out:
# 'Siva'

# %%
data[-2]
# Out:
# 'Rohit'

# %% [markdown]
# #### List Appending

# %%
data.append("Venu")

# %%
data[-1]
# Out:
# 'Venu'

# %%
data
# Out:
# ['Banana', 'Apples', 'Rice', 10, 'Rohit', 'Siva', 'Venu']

# %%
len(data)
# Out:
# 7

# %% [markdown]
# ### Remove item from list by index

# %%
data.pop(3)
# Out:
# 10

# %%
len(data)
# Out:
# 6

# %%
data
# Out:
# ['Banana', 'Apples', 'Rice', 'Rohit', 'Siva', 'Venu']

# %%
data_2 = ["Anamika", "Mallika", "Kanchana"]

# %% [markdown]
# #### List Extension

# %%
data.extend(data_2)

# %%
data
# Out:
# ['Banana',
#  'Apples',
#  'Rice',
#  'Rohit',
#  'Siva',
#  'Venu',
#  'Anamika',
#  'Mallika',
#  'Kanchana']

# %% [markdown]
# #### Remove item from List

# %%
data.remove("Rice")

# %%
data
# Out:
# ['Banana', 'Apples', 'Rohit', 'Siva', 'Venu', 'Anamika', 'Mallika', 'Kanchana']

# %% [markdown]
# #### Reverse a List

# %%
data.reverse()

# %%
data
# Out:
# ['Kanchana', 'Mallika', 'Anamika', 'Venu', 'Siva', 'Rohit', 'Apples', 'Banana']

# %% [markdown]
# #### List Slicing

# %%
group_1 = data[:4]

# %%
group_2 = data[4:]

# %%
group_1
# Out:
# ['Kanchana', 'Mallika', 'Anamika', 'Venu']

# %%
group_2
# Out:
# ['Siva', 'Rohit', 'Apples', 'Banana']

# %% [markdown]
# #### Sort a list ascending order

# %%
data.sort()

# %%
data
# Out:
# ['Anamika', 'Apples', 'Banana', 'Kanchana', 'Mallika', 'Rohit', 'Siva', 'Venu']

# %% [markdown]
# #### Sort a list decending order

# %%
sorted(data, reverse=True)
# Out:
# ['Venu', 'Siva', 'Rohit', 'Mallika', 'Kanchana', 'Banana', 'Apples', 'Anamika']
